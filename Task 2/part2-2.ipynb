# %%
import pandas as pd
import re
import time
import numpy as np
from itertools import combinations


# THIS CELL IS ALL LAB CODE AND PREPROCESSING!!

# Load datasets
acm = pd.read_csv("ACM.csv")
dblp = pd.read_csv("DBLP2.csv", encoding="latin1") # breaks without this
perfect_mapping = pd.read_csv("DBLP-ACM_perfectMapping.csv")

# (a) Concat
def concatenate_record(rec):
    return " ".join(str(val) for val in rec.values)
    
def preprocess(text):
    # (b) lowercase
    text = text.lower()
    # (c) convert multiple spaces to one
    text = re.sub(r'\s+', ' ', text)
    return text.strip()
    

# Preprocess 
for df in [acm, dblp]:
    for col in ['title', 'authors', 'venue']:
        if col != "id":
            df[col] = df[col].astype(str).apply(preprocess)

# Keep IDs separately
acm_ids = acm["id"].tolist()
dblp_ids = dblp["id"].tolist()


# Should we drop id here?
acm_strings = acm.drop('id', axis=1).apply(concatenate_record).tolist()
dblp_strings = dblp.drop('id', axis=1).apply(concatenate_record).tolist()

doc_ids = acm_ids + dblp_ids
doc_strings = acm_strings + dblp_strings

def get_minhash_arr(num_hashes:int,vocab:dict):
    """
    """
    length = len(vocab.keys())
    arr = np.zeros((num_hashes,length))
    for i in range(num_hashes):
        permutation = np.random.permutation(len(vocab.keys()))
        arr[i,:] = permutation.copy()
    return arr.astype(int)
def get_signature(minhash:np.ndarray, vector:np.ndarray):
    """
    """
    idx = np.nonzero(vector)[0].tolist()
    shingles = minhash[:,idx]
    signature = np.min(shingles,axis=1)
    return signature

def jaccard_similarity(set1, set2):
    intersection_size = len(set1.intersection(set2))
    union_size = len(set1.union(set2))
    return intersection_size / union_size if union_size != 0 else 0.0

def compute_signature_similarity(signature_1, signature_2):
    """
    """
    # Ensure the matrices have the same shape
    if signature_1.shape != signature_2.shape:
        raise ValueError("Both signature matrices must have the same shape.")
    # Count the number of rows where the two matrices agree
    agreement_count = np.sum(signature_1 == signature_2)
    # Calculate the similarity
    similarity = agreement_count / signature_2.shape[0]

    return similarity

class LSH:
    """
    Implements the Locality Sensitive Hashing (LSH) technique for approximate
    nearest neighbor search.
    """
    buckets = []
    counter = 0

    def __init__(self, b: int):
        """
        Initializes the LSH instance with a specified number of bands.

        Parameters:
        - b (int): The number of bands to divide the signature into.
        """
        self.b = b
        for i in range(b):
            self.buckets.append({})

    def make_subvecs(self, signature: np.ndarray) -> np.ndarray:
        """
        Divides a given signature into subvectors based on the number of bands.

        Parameters:
        - signature (np.ndarray): The MinHash signature to be divided.

        Returns:
        - np.ndarray: A stacked array where each row is a subvector of the signature.
        """
        l = len(signature)
        assert l % self.b == 0
        r = int(l / self.b)
        subvecs = []
        for i in range(0, l, r):
            subvecs.append(signature[i:i+r])
        return np.stack(subvecs)

    def add_hash(self, signature: np.ndarray):
        """
        Adds a signature to the appropriate LSH buckets based on its subvectors.

        Parameters:
        - signature (np.ndarray): The MinHash signature to be hashed and added.
        """
        subvecs = self.make_subvecs(signature).astype(str)
        for i, subvec in enumerate(subvecs):
            subvec = ','.join(subvec)
            if subvec not in self.buckets[i].keys():
                self.buckets[i][subvec] = []
            self.buckets[i][subvec].append(self.counter)
        self.counter += 1

    def check_candidates(self) -> set:
        """
        Identifies candidate pairs from the LSH buckets that could be potential near duplicates.

        Returns:
        - set: A set of tuple pairs representing the indices of candidate signatures.
        """
        candidates = []
        for bucket_band in self.buckets:
            keys = bucket_band.keys()
            for bucket in keys:
                hits = bucket_band[bucket]
                if len(hits) > 1:
                    candidates.extend(combinations(hits, 2))
        return set(candidates)


def shingle(text: str, k: int)->set:
    """
    Create a set of 'shingles' from the input text using k-shingling.

    Parameters:
        text (str): The input text to be converted into shingles.
        k (int): The length of the shingles (substring size).

    Returns:
        set: A set containing the shingles extracted from the input text.
    """
    shingle_set = []
    for i in range(len(text) - k+1):
        shingle_set.append(text[i:i+k])
    return set(shingle_set)
def build_vocab(shingle_sets: list)->dict:
    """
    Constructs a vocabulary dictionary from a list of shingle sets.

    This function takes a list of shingle sets and creates a unified vocabulary
    dictionary. Each unique shingle across all sets is assigned a unique integer
    identifier.

    Parameters:
    - shingle_sets (list of set): A list containing sets of shingles.

    Returns:
    - dict: A vocabulary dictionary where keys are the unique shingles and values
      are their corresponding unique integer identifiers.

    Example:
    sets = [{"apple", "banana"}, {"banana", "cherry"}]
    build_vocab(sets)
    {'apple': 0, 'cherry': 1, 'banana': 2}  # The exact order might vary due to set behavior
    """
    full_set = {item for set_ in shingle_sets for item in set_}
    vocab = {}
    for i, shingle in enumerate(list(full_set)):
        vocab[shingle] = i
    return vocab
def one_hot(shingles: set, vocab: dict):
    vec = np.zeros(len(vocab))
    for shingle in shingles:
        idx = vocab[shingle]
        vec[idx] = 1
    return vec

# %%
# Shingling

k = 2
shingles = []
for sentence in doc_strings:
    shingles.append(shingle(sentence,k))
vocab = build_vocab(shingles)
print(f"Number of vocabulary is:{len(vocab)}")
shingles_1hot = []
for shingle_set in shingles:
    shingles_1hot.append(one_hot(shingle_set,vocab))
shingles_1hot = np.stack(shingles_1hot)


minhash_arr =  get_minhash_arr(200,vocab)
signatures = []
for vector in shingles_1hot:
    signatures.append(get_signature(minhash_arr,vector))
signatures = np.stack(signatures)
signatures.shape


b = 20   # number of buckets
lsh = LSH(b)
for signature in signatures:
    lsh.add_hash(signature)
candidate_pairs = lsh.check_candidates()
print(len(candidate_pairs))

candidates = []
for i, j in candidate_pairs:
    id1, id2 = doc_ids[i], doc_ids[j]

    # AI code, idk its broken
    if i < len(acm_ids) and j >= len(acm_ids):
        candidates.append((id1, id2))
    elif j < len(acm_ids) and i >= len(acm_ids):
        candidates.append((id2, id1))



perfect_set = set(zip(perfect_mapping["idACM"], perfect_mapping["idDBLP"]))
reported_set = set(candidates)

correct_matches = reported_set & perfect_set
precision = len(correct_matches) / len(reported_set) if reported_set else 0

print("Total ACM docs:", len(acm_ids))
print("Total DBLP docs:", len(dblp_ids))

print(f"LSH Precision: {precision:.4f}")
print(f"Candidate pairs: {len(reported_set)}")
print(f"Correct matches: {len(correct_matches)}")
# Out:
# Number of vocabulary is:1385
# 10
# Total ACM docs: 2294
# Total DBLP docs: 2616
# LSH Precision: 0.0000
# Candidate pairs: 0
# Correct matches: 0

# %%
print("ACM ID sample:", acm_ids[:5])
print("DBLP ID sample:", dblp_ids[:5])
print("Perfect mapping sample:", perfect_mapping.head())

# Check overlap
print("Any ACM IDs in mapping?", any(i in perfect_mapping["idACM"].values for i in acm_ids))
print("Any DBLP IDs in mapping?", any(i in perfect_mapping["idDBLP"].values for i in dblp_ids))

# %%
dblp_strings
# Out:
# ["semantic integration of environmental models for application to global information systems and decision-making estimation of query-result distribution and its application in parallel-join load balancing incremental maintenance for non-distributive aggregate functions cost-based selection of path expression processing algorithms in object-oriented databases benchmarking spatial join operations with spatial output efficient geometry-based similarity search of 3d spatial databases mining the world wide web: an information search approach - book review enhanced abstract data types in object-relational databases report on dart '96: databases: active and real-time (concepts meet practice) unisql's next-generation object-relational database management system dual-buffering strategies in object bases aurora: a data stream management system priority assignment in real-time active databases wavecluster: a wavelet based clustering approach for spatial data in very large databases approximate query mapping: accounting for translation closeness sprint: a scalable parallel classifier for data mining snowball: a prototype system for extracting relations from large text collections a framework for implementing hypothetical queries parametric query optimization lineage tracing for general data warehouse transformations report on the acm fourth international workshop on data warehousing and olap (dolap 2001) approximating aggregate queries about web pages via random walks a query language for a web-site management system supporting periodic authorizations and temporal reasoning in database access control free parallel data mining high level indexing of user-defined types pc database systems - present and future form-based proxy caching for database-backed web sites a logical view of structured files dbglobe: a service-oriented p2p system for global computing database patchwork on the internet scientific databases - state of the art and future directions a generic approach to bulk loading multidimensional index structures data bubbles for non-vector data: speeding-up hierarchical clustering in arbitrary metric spaces efficient snapshot differential algorithms for data warehousing integrating triggers and declarative constraints in sql database sytems efficient ir-style keyword search over relational databases indexing of now-relative spatio-bitemporal data temporal coalescing with now, granularity, and incomplete information database research at ut arlington why decision support fails and how to fix it a low-cost storage server for movie on demand databases generating call-level interfaces for advanced database application programming clustering by pattern similarity in large data sets mocha: a database middleware system featuring automatic deployment of application-specific functionality fact: a learning based web query processing system sql multimedia and application packages (sql/mm) bellcore's adapt/x harness system for managing information on internet and intranets xml data management go native or spruce up relational systems? (panel abstract) an overview of data warehousing and olap technology staggered striping in multimedia information systems multimedia streaming in large-scale sensor networks with mobile swarms how to modify sql queries in order to guarantee sure answers materialization: a powerful and ubiquitous abstraction pattern dynamic content acceleration: a caching solution to enable scalable dynamic web page generation data modelling in the large updating xml research in information managment at dublin city university the multidimensional database system rasdaman analyzing energy behavior of spatial access methods for memory-resident data the value of merge-join and hash-join in sql server efficient execution of joins in a star schema picodmbs: scaling down database techniques for the smartcard multi-dimensional substring selectivity estimation the intrinsic problems of structural heterogeneity and an approach to their soluti ...
#  "d. scott mackay viswanath poosala, yannis e. ioannidis themistoklis palpanas, richard sidle, hamid pirahesh, roberta cochrane zhao-hui tang, georges gardarin, jean-robert gruser erik g. hoel, hanan samet daniel a. keim aris m. ouksel praveen seshadri nandit soparkar, krithi ramamritham phil janus, albert d'andrea alfons kemper, donald kossmann nesime tatbul, daniel j. abadi, c. erwin, anurag maskey, mitch cherniack, alex rasin, christian convey, a. singer, eduardo f. galvez, r. yan, ugur çetintemel, ying xing, stanley b. zdonik, michael stonebraker, donald carney, m. hatoun rajendran m. sivasankaran, bhaskar purimetla, john a. stankovic, krithi ramamritham, donald f. towsley surojit chatterjee, gholamhosein sheikholeslami, aidong zhang hector garcia-molina, kevin chen-chuan chang john c. shafer, rakesh agrawal, manish mehta jeff pavel, luis gravano, aleksandr voskoboynik, eugene agichtein, viktoriya sokolova timothy griffin, richard hull raymond t. ng, timos k. sellis, yannis e. ioannidis, kyuseok shim yingwei cui, jennifer widom joachim hammer jittat fakcharoenphol, steve chien, ziv bar-yossef, alexander berg, dror weitz dan suciu, daniela florescu, alon y. levy, mary f. fernandez elena ferrari, pierangela samarati, claudio bettini, elisa bertino bin li, dennis shasha brian t. tran, jyh-herng chow, michelle jou, jean grandbois, yun wang, you-chin fuh, weidong chen, nelson mendonça mattos philip a. bernstein jeffrey f. naughton, qiong luo tova milo, serge abiteboul, sophie cluet evaggelia pitoura, serge abiteboul, michalis vazirgiannis, dieter pfoser, george samaras reinhard braumandl, alfons kemper, donald kossmann yannis e. ioannidis, maria zemankova bernhard seeger, peter widmayer, jochen van den bercken jörg sander, jianjun zhou hector garcia-molina, wilburt labio roberta cochrane, hamid pirahesh, nelson mendonça mattos yannis papakonstantinou, luis gravano, vagelis hristidis simonas saltenis, christian s. jensen curtis e. dyreson sharma chakravarthy, y. alp aslandogan, ramez elmasri, leonidas fegaras, jung-hwan oh kevin strehlo, ralph kimball alexandros biliris, banu özden, abraham silberschatz, rajeev rastogi theo härder, norbert ritter, udo nink haixun wang, wei wang, philip s. yu, jiong yang manuel rodriguez-martinez, joseph jájá, john m. mcgann, nick roussopoulos, zhexuan song, stephen kelley, vadim katz zengping tian, hongjun lu, yanlei diao, songting chen jim melton, andrew eisenberg amit p. sheth per-åke larson surajit chaudhuri, umeshwar dayal steven berson, richard r. muntz, shahram ghandeharizadeh, xiangyu ju mario gerla, kaixin xu hans-joachim klein alain pirotte, esteban zimányi, tatiana yakusheva, david massart debra e. vandermeer, krithi ramamritham, helen m. thomas, anindya datta, kaushik dutta martin bertram daniel s. weld, zachary g. ives, igor tatarinov, alon y. halevy alan f. smeaton, mark roantree andreas dehmel, peter baumann, norbert widmann, roland ritsch, paula furtado anand sivasubramaniam, sudhanva gurumurthi, narayanan vijaykrishnan, ning an, mary jane irwin, mahmut t. kandemir goetz graefe andreas weininger luc bouganim, patrick valduriez, philippe pucheral, christophe bobineau divesh srivastava, olga kapitskaia, raymond t. ng, h. v. jagadish theo härder, joachim thomas, günter sauter c. mohan rafael camps scott shenker phillip b. gibbons, srinivasan seshan, suman kumar nath, amol deshpande zhao-hui tang, jean-robert gruser, georges gardarin wilburt labio, jun yang, hector garcia-molina xiaolei qian andré eickler, alfons kemper, donald kossmann yannis papakonstantinou, vagelis hristidis, nick koudas ling liu mukesh mulchandani, elke a. rundensteiner, xin zhang, brian murphy, steffen christ carol small, alexandra poulovassilis alexander aiken, jennifer widom, joseph m. hellerstein babis theodoulidis, george karvelis, jayant chaudhary, aziz ait-braham, simon sou, george andrianopoulos hamid pirahesh, inderpal singh mumick, raghu ramakrishnan, sheldon j. finkelstein wolfgang klas, frank moser, a ...
#  'sigmod record vldb vldb vldb vldb sigmod conference sigmod record vldb j. sigmod record sigmod record vldb sigmod conference vldb j. vldb j. vldb j. vldb sigmod conference sigmod conference vldb j. vldb sigmod record vldb sigmod record vldb sigmod conference vldb vldb vldb vldb j. sigmod record sigmod conference vldb vldb vldb vldb vldb vldb vldb j. sigmod conference sigmod record sigmod record vldb vldb sigmod conference sigmod conference sigmod conference sigmod record vldb sigmod conference sigmod record sigmod conference sigmod record sigmod record vldb sigmod conference sigmod record sigmod conference sigmod record sigmod conference vldb vldb sigmod conference vldb vldb vldb j. sigmod conference sigmod record vldb sigmod conference vldb vldb sigmod record vldb sigmod conference sigmod record sigmod conference vldb j. acm trans. database syst. sigmod conference acm trans. database syst. vldb sigmod conference vldb vldb sigmod conference sigmod conference sigmod record vldb sigmod record sigmod conference vldb vldb vldb sigmod conference acm trans. database syst. sigmod record sigmod record sigmod conference sigmod record vldb vldb sigmod conference vldb vldb acm trans. database syst. sigmod conference vldb vldb acm trans. database syst. sigmod conference acm trans. database syst. sigmod conference sigmod record sigmod record sigmod conference sigmod record vldb sigmod record vldb vldb vldb j. sigmod record sigmod record vldb vldb sigmod conference acm trans. database syst. sigmod conference vldb sigmod record vldb sigmod record sigmod record sigmod conference sigmod conference sigmod conference sigmod record sigmod conference acm trans. database syst. sigmod conference sigmod record vldb sigmod conference sigmod conference sigmod conference sigmod conference sigmod conference acm trans. database syst. vldb sigmod conference sigmod conference sigmod conference sigmod conference vldb vldb sigmod record sigmod record sigmod conference vldb vldb vldb sigmod conference sigmod record vldb vldb acm trans. database syst. sigmod conference sigmod conference sigmod conference sigmod conference vldb vldb sigmod record sigmod record vldb vldb j. sigmod conference sigmod record sigmod record sigmod conference sigmod conference vldb vldb j. vldb j. vldb sigmod conference sigmod record sigmod record sigmod record sigmod conference sigmod conference sigmod conference vldb acm trans. database syst. sigmod conference vldb sigmod conference sigmod conference vldb j. acm trans. database syst. vldb sigmod record vldb vldb sigmod conference sigmod conference sigmod conference vldb vldb vldb j. sigmod record vldb vldb sigmod record sigmod record sigmod conference vldb vldb vldb sigmod record vldb sigmod conference sigmod record vldb j. vldb j. sigmod conference vldb sigmod conference vldb vldb j. sigmod conference vldb sigmod conference acm trans. database syst. vldb vldb sigmod conference sigmod conference vldb vldb sigmod record sigmod conference vldb sigmod conference sigmod conference vldb j. sigmod conference vldb acm trans. database syst. sigmod conference vldb sigmod conference vldb vldb sigmod record vldb vldb sigmod conference vldb j. vldb j. sigmod conference sigmod conference sigmod conference vldb vldb j. acm trans. database syst. sigmod record sigmod conference sigmod conference sigmod conference sigmod record sigmod conference vldb j. vldb sigmod record sigmod record sigmod record sigmod conference sigmod conference vldb vldb sigmod conference vldb j. acm trans. database syst. sigmod record sigmod record sigmod record sigmod record sigmod conference sigmod record sigmod conference vldb sigmod conference sigmod record vldb sigmod conference vldb sigmod record vldb acm trans. database syst. sigmod conference sigmod conference vldb sigmod record sigmod record vldb sigmod conference vldb sigmod conference vldb sigmod conference sigmod record sigmod record sigmod conference vldb j. vldb vldb vldb j. sigmod conference vldb vldb vldb vl ...
#  '1999 1996 2002 1996 1995 1999 2002 1998 1997 1996 1994 2003 1996 2000 2001 1996 2001 1997 1997 2001 2002 2000 1997 1996 1998 1999 1994 2001 1998 2003 1999 1994 1997 2003 1996 1996 2003 2002 2003 2003 1995 1994 1999 2002 2000 2000 2001 1996 2001 1997 1994 2003 1994 1994 2001 1994 2001 2002 1998 2001 1999 2002 2000 1999 1999 1999 1996 2003 2003 1995 1998 1997 1997 2001 2002 2002 1996 1995 1994 1996 1995 1998 1999 1995 1994 1995 2000 2000 2002 2001 2002 2001 2000 1994 1995 2000 1994 2001 1996 1994 1999 1999 2001 1997 2003 2003 1999 1999 2003 1998 2001 1996 1994 1999 1997 1999 2002 2001 1999 1995 1999 1994 2001 2003 1997 2001 1994 1999 1996 1995 2002 2003 1995 1998 2002 1995 2001 1997 1999 1995 2003 1994 1998 2001 1996 2002 1997 2000 1995 2002 1996 1996 2000 1994 1995 2002 2001 1997 1996 2002 2003 2002 1995 2003 1995 2002 1999 1994 1997 1996 1998 1996 1994 1996 1998 2002 1994 1998 2001 2000 1994 2003 1995 1994 2002 1996 1999 2002 2002 1995 1994 1998 2002 2002 1996 2000 2002 1995 2000 2002 2003 1996 2003 2003 1998 2001 1996 1996 1998 2003 2003 2002 2001 1997 2000 1998 2000 1998 1997 2001 2002 1996 2000 2001 1995 2002 1998 2002 2003 1994 1999 2001 1999 1995 1994 2003 1994 1996 2003 1999 1995 2003 2003 1998 2002 1996 1995 2003 1994 1998 1999 2002 1998 1995 2002 2003 1998 2003 1997 2003 2003 1997 2003 1999 2000 1995 1999 2000 1996 1999 2002 1996 1994 1994 2003 2001 2002 2001 1998 2000 2000 2003 1999 2000 1997 1998 2001 1997 1995 1994 2001 2001 2002 2003 2003 2002 2000 2001 1997 2001 1994 1996 1999 1996 2001 1998 1995 1995 2001 2000 2001 2001 1994 1997 2000 2001 2002 1998 2003 1999 1995 2002 2003 1999 1998 1997 2001 1996 1997 1998 2000 1994 1994 2003 2001 1999 2001 2002 1997 2000 2002 1994 2003 2001 2002 1995 2003 1997 1998 1994 1998 2001 1998 1994 2001 2003 1996 1996 2002 2001 2003 1998 1998 1996 2000 1994 1994 2001 1997 1996 2002 1997 1999 1995 1996 1994 1997 1996 2003 1999 1998 2001 2003 2003 1998 1999 2002 2002 1995 2003 2001 1996 1998 2003 1999 2001 2000 1998 2001 2002 2001 2003 1998 1996 1994 2003 2002 1994 1998 1999 1997 1997 1995 1996 1995 1995 1998 2000 1995 1998 1996 2003 2002 2001 1997 2002 1994 2003 2001 2000 1995 1998 1998 2002 2002 1999 1997 1998 1996 1995 1999 2000 2000 1996 1997 1998 2001 1998 2003 1994 2000 1994 2003 2000 2003 1994 1997 1998 2003 1995 2000 1999 2001 1999 2002 1998 2000 2002 2003 1995 1998 2002 1998 1999 2002 2002 2002 2000 2003 1996 2002 2001 2001 1998 1999 1999 1996 1999 2003 1997 1999 1999 2003 2000 1995 1996 1998 2003 2002 1998 1996 1995 1999 2001 2000 1998 2000 1997 2002 2000 2001 2000 1997 1994 1998 1997 2002 2003 1998 2002 1998 2000 2002 2002 2000 1995 2000 1999 2003 2001 1994 1996 2002 1998 1998 1994 2003 2001 1996 2002 2002 2001 1997 1999 1995 1997 1996 2003 2000 2001 2003 1998 1995 2003 1998 2003 2002 2000 1996 2002 2001 1996 1996 2000 2002 1997 2002 1995 1999 1997 2003 2002 2000 2001 2002 2002 2002 2003 2003 2001 1999 2001 2000 2001 2000 2003 2001 1998 1994 2000 1999 1999 1996 1994 1998 2000 2003 1996 1998 1998 1994 2000 1999 2003 2000 2000 1995 1998 1994 2000 1995 2003 1998 1997 1999 2001 2001 1999 2001 1998 2001 2003 1998 2003 2003 1998 2002 1995 2003 2003 1998 2002 1999 2002 1999 1996 2002 2003 1998 1998 1996 1996 2000 2002 1994 2002 2002 1998 2000 1994 1998 2003 1995 2003 2003 2001 1998 2003 1995 2003 1994 1997 2000 2001 1996 2003 1994 2003 1996 2001 1994 2003 1998 1994 1995 1998 1995 2000 1994 1994 1996 2003 2000 1997 2003 1996 2003 1997 1997 2003 2001 2002 1998 2002 1997 2000 1996 1995 1997 2002 1998 1999 1998 1994 2001 2002 2002 1995 1995 2002 2000 1997 1996 2001 2001 2000 2003 2003 2001 2002 1998 2002 1994 1995 2000 1999 2002 2002 1999 1998 2002 2001 1998 1999 2003 2001 2001 1995 2000 1995 1998 1998 1998 1998 1997 1998 1996 2001 2002 2003 2000 1998 2000 2002 1999 1995 1995 2000 1998 1996 1999 2002 2003 1996 1998 1994 1996 2001 1998 2000 1994 2003 1998 1994 1999 2002 2003 1998 1997 2003 1997 2001 1996 1994 1999 2001 2002 2000 1995 1998 1998 1997 2000 1995 2000 1994 2001 2002 2001 199 ...
